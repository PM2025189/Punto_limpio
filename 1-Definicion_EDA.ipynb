# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# #  Punto limpio, punto sesgo
#
# Acceso desigual a los Puntos Limpios en Madrid: un análisis socioespacial

# %% [markdown]
# ### TEMA

# %% [markdown]
# Distribución socioespacial de infraestructuras ambientales en Madrid y su relación con la renta y las características territoriales.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# - La distribución de los puntos limpios podría reflejar sesgos sociales o territoriales.
# - Los barrios más ricos estarían más alejados de los puntos limpios fijos.
# - Las personas que podrían necesitar residuos de alto valor como fuente de ingresos tienen menos acceso a los puntos limpios que los reciben.

# %% [markdown]
# hipotesis_1 = sería que existen sesgos sociales y territoriales significativos en la provisión y el uso de los Puntos Limpios en Madrid, lo que resulta en una inequidad en las prácticas de gestión de residuos.

# %% [markdown]
# hipotesis_2 = "Identificar posibles sesgos sociales o territoriales en la provisión de infraestructuras de reciclaje y en las prácticas de gestión de residuos."
#
# hipotesis_3 Los barrios con un perfil socioeconómico más alto y/o una reputación "ecológica" más fuerte se beneficiarán de una mejor accesibilidad a los Puntos Limpios .
#
# hipotesis_4 = "La tasa de uso de los Puntos Limpios será mayor en los barrios con un perfil socioeconómico más alto y/o una reputación "ecológica" más fuerte, incluso con una accesibilidad similar.."
#
# hipotesis_5 = "Los barrios con alta proporción de residentes con estudios universitarios pueden utilizar paradójicamente menos estos centros."

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
# guarda en variables los datasets y su fuente
df_1 = pd.DataFrame(renda por distrito)
fuente_1 = "INE"
# df_2 = pd.DataFrame(puntos limpios fijos)
# fuente_2 = "Ayuntamiento de Madrid"
# df_3 = pd.DataFrame(problematicas sociales)
# fuente_3 = "Ayuntamiento de Madrid"
# df_4 = pd.DataFrame(padron estadisticas 2025)
# fuente_4 = "Ayuntamiento de Madrid"
# df_5 = pd.DataFrame(fuentes)
# fuente_5 = "Ayuntamiento de Madrid"
# .df_6 = pd.DataFrame(indicadores por distrito)
# fuente_6 = "Ayuntamiento de Madrid"..
# df_7 = pd.DataFrame(avisos recibidos)
# fuente_7 = "Ayuntamiento de Madrid"
# .df_8 = pd.DataFrame(avisos tramitidos)
# fuente_8= "Ayuntamiento de Madrid"..
#df_9 = pd.DataFrame(parques y jardines)
# fuente_9= "Ayuntamiento de Madrid".
df_10 = pd.DataFrame(parques y jardines)
# fuente_10= "Ayuntamiento de Madrid".

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
import pandas as pd
# Primer dataset
df_1 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/renda por distrito madrid.csv', sep=";")
df_1.head()
# Out:
#      Municipios                   Distritos  Secciones  \
# 0  28079 Madrid                         NaN        NaN
# 1  28079 Madrid  2807901 Madrid distrito 01        NaN
# 2  28079 Madrid  2807902 Madrid distrito 02        NaN
# 3  28079 Madrid  2807903 Madrid distrito 03        NaN
# 4  28079 Madrid  2807904 Madrid distrito 04        NaN
#
#   Indicadores de renta media y mediana  Periodo   Total
# 0         Renta neta media por persona     2022  18.632
# 1         Renta neta media por persona     2022  20.587
# 2         Renta neta media por persona     2022  21.383
# 3         Renta neta media por persona     2022  25.407
# 4         Renta neta media por persona     2022  28.140

# %%
# Siguiente dataset...
df_2 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/puntos-limpios-fijos.csv', sep=";")
df_2.head(2)
# Out:
#        PK                                             NOMBRE  \
# 0   19960  Punto Limpio Fijo del Ayuntamiento de Madrid. ...
# 1  138166  Punto Limpio Fijo del Ayuntamiento de Madrid. ...
#
#    DESCRIPCION-ENTIDAD                                            HORARIO  \
# 0                  NaN  De lunes a sábados de 8 a 20 horas. Domingos y...
# 1                  NaN  De lunes a sábados de 8 a 20 horas. Domingos y...
#
#    EQUIPAMIENTO                                        TRANSPORTE  \
# 0           NaN  Metro: Méndez Álvaro (línea 6)Bus: 148, 102, 152
# 1           NaN            Metro: Barajas (línea 8)Bus: 105 , 115
#
#                                          DESCRIPCION  ACCESIBILIDAD  \
# 0  El traslado de residuos correrá a cuenta de la...              0
# 1  El traslado de residuos correrá a cuenta de la...              0
#
#                                          CONTENT-URL         NOMBRE-VIA  ...  \
# ...

# %%
df_3 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/problematicas_sociales.csv', sep=";")
df_3.head()
# Out:
#    SECUENCIA CENTRO_COD      CENTRO_DESC  DISTRITO_COD          DISTRITO_DESC  \
# 0          1   CSS08010     CSS Badalona             8  FUENCARRAL - EL PARDO
# 1          2   CSS13020    CSS San Diego            13     PUENTE DE VALLECAS
# 2          3   CSS06020  CSS María Zayas             6                 TETUÁN
# 3          4   CSS08010     CSS Badalona             8  FUENCARRAL - EL PARDO
# 4          5   CSS06020  CSS María Zayas             6                 TETUÁN
#
#    BARRIO_COD    BARRIO_DESC  SECCION_CENSAL TRAMO_EDAD NACIONALIDAD SEXO  \
# 0         5.0         LA PAZ              90    75 - 79     Española    M
# 1         2.0      SAN DIEGO              66    55 - 59   Extranjera    M
# 2         1.0  BELLAS VISTAS              19    25 - 29   Extranjera    M
# 3         6.0       VALVERDE             117      >= 85     Española    M
# 4         1.0  BELLAS VISTAS              19    25 - 29   Extranjera    M
#
# ...

# %%
df_4 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/padron_estadisticas202506.csv', sep=";")
df_4.head()
# Out:
#    COD_DISTRITO         DESC_DISTRITO  COD_DIST_BARRIO           DESC_BARRIO  \
# 0             2  ARGANZUELA                      203.0  CHOPERA
# 1            12  USERA                          1203.0  SAN FERMIN
# 2             4  SALAMANCA                       403.0  FUENTE DEL BERRO
# 3             3  RETIRO                          301.0  PACIFICO
# 4             4  SALAMANCA                       401.0  RECOLETOS
#
#    COD_BARRIO  COD_DIST_SECCION  COD_SECCION COD_EDAD_INT  ESPANOLESHOMBRES  \
# 0         3.0            2036.0         36.0           52                 7
# 1         3.0           12029.0         29.0           70                 1
# 2         3.0            4050.0         50.0           78                 2
# 3         1.0            3015.0         15.0           97                 0
# 4         1.0            4011.0         11.0           87                 2
#
#    ESPANOLESMUJERES  EXTRANJEROSHOMBRES  EXTRANJEROSMUJERES  \
# ...

# %%
df_5 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/fuentes202507.csv', sep=";")
df_5.head()
# Out:
#          ID DESC_CLASIFICACION  COD_BARRIO        BARRIO  COD_DISTRITO  \
# 0  10040803   Fuentes de beber         166  VALDEFUENTES            16
# 1  10040808   Fuentes de beber         166  VALDEFUENTES            16
# 2  10040811   Fuentes de beber         131     ENTREVIAS            13
# 3  10040812   Fuentes de beber         131     ENTREVIAS            13
# 4  10046448   Fuentes de beber          11       PALACIO             1
#
#              DISTRITO     ESTADO  COORD_GIS_X  COORD_GIS_Y SISTEMA_COORD  ...  \
# 0           HORTALEZA  OPERATIVO   447330.063  4481612.220        ETRS89  ...
# 1           HORTALEZA  OPERATIVO   446829.141  4480378.512        ETRS89  ...
# 2  PUENTE DE VALLECAS  OPERATIVO   443190.725  4468707.601        ETRS89  ...
# 3  PUENTE DE VALLECAS  OPERATIVO   442914.010  4468479.016        ETRS89  ...
# 4              CENTRO  OPERATIVO   439286.799  4473557.836        ETRS89  ...
#
#    NUM_VIA  COD_POSTAL         DIRECCION_AUX         NDP  \
# ...

# %%
df_6 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/estudiospanel_indicadores_distritos_barrios.csv', sep=";")
df_6.head()
# Out:
#    Orden  Periodo panel            ciudad  cod_distrito distrito  cod_barrio  \
# 0      1           2020  Ciudad de Madrid           NaN      NaN         NaN
# 1      2           2020  Ciudad de Madrid           NaN      NaN         NaN
# 2      3           2020  Ciudad de Madrid           NaN      NaN         NaN
# 3      4           2020  Ciudad de Madrid           NaN      NaN         NaN
# 4      5           2020  Ciudad de Madrid           NaN      NaN         NaN
#
#   barrio   año fecha_indicador                    fuente_indicador  \
# 0    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 1    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 2    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 3    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
# 4    NaN  2019      01/01/2019  Estadística Ayuntamiento de Madrid
#
#                                      categoría_1              categoría_2  \
# ...

# %%
df_7 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/avisos_recibidos202507.csv', sep=";")
df_7.head()
# Out:
#    TIPO_INCIDENCIA_ID TIPO_INCIDENCIA  CANAL_DE_ENTRADA_ID  \
# 0                   0           Aviso                  NaN
# 1                   0           Aviso                  NaN
# 2                   0           Aviso                  NaN
# 3                   0           Aviso                  1.0
# 4                   0           Aviso                  NaN
#
#          CANAL_DE_ENTRADA FECHA_DE_RECEPCION HORA_DE_RECEPCION  \
# 0      Madrid Móvil (iOS)         01/01/2025          00:11:19
# 1  Madrid Móvil (Android)         01/01/2025          01:45:00
# 2  Madrid Móvil (Android)         01/01/2025          01:46:39
# 3                     010         01/01/2025          01:57:12
# 4  Madrid Móvil (Android)         01/01/2025          01:59:24
#
#    CATEGORIA_NIVEL1_ID                             CATEGORIA_NIVEL1  \
# 0                  105  Vehículos abandonados. Retirada de vehículo
# 1                   48                            Alumbrado público
# ...

# %%
df_8 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/avisos_tramitados202507.csv', sep=";")
df_8.head()
# Out:
# /var/folders/mh/cyn_blp16md9ky8l15xls3gr0000gn/T/ipykernel_23131/2557929916.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_7 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/avisos_tramitados202507.csv', sep=";")
#    TIPO_INCIDENCIA_ID TIPO_INCIDENCIA  CANAL_DE_ENTRADA_ID  \
# 0                   0           Aviso                  NaN
# 1                   0           Aviso                  NaN
# 2                   0           Aviso                  NaN
# 3                   0           Aviso                  1.0
# 4                   0           Aviso                  NaN
#
#          CANAL_DE_ENTRADA FECHA_DE_RECEPCION HORA_DE_RECEPCION  \
# 0      Madrid Móvil (iOS)         01/01/2025          00:11:19
# 1  Madrid Móvil (Android)         01/01/2025          01:45:00
# 2  Madrid Móvil (Android)         01/01/2025          01:46:39
# 3                     010         01/01/2025          01:57:12
# ...

# %%
df_9 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/parques-jardines.csv', sep=";", encoding='latin1')
df_9.head()
# Out:
#          PK                            NOMBRE  \
# 0   6070995         Jardines Gregorio Ordóñez
# 1   6010361  Jardines San Francisco el Grande
# 2   5964519        Jardines de Andrés Saborit
# 3   5896013        Jardines de El Buen Retiro
# 4  10984428        Jardines de Gloria Fuertes
#
#                                  DESCRIPCION-ENTIDAD  \
# 0  Los jardines en memoria de Gregorio Ordóñez cu...
# 1  Los jardines de San Francisco el Grande están ...
# 2  Los Jardines de Andrés Saborit se encuentran e...
# 3  El Parque del Buen Retiro, conocido simplement...
# 4  Este jardín rinde homenaje a la célebre poetis...
#
#                                              HORARIO  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Horario del parque    Primavera y verano (de a...
# 4                                                NaN
#
# ...

# %%
df_10 = pd.read_csv('/Users/pm/Desktop/Punto Limpio/qualidad del aire/CALIDAD_AIRE_HORARIOS20250513.csv', sep=";", encoding='latin1')
df_10.head()
# Out:
#    ï»¿PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 0            28         79        11        12  28079011_12_8  2025    1    1
# 1            28         79        11        12  28079011_12_8  2025    1    2
# 2            28         79        11        12  28079011_12_8  2025    1    3
# 3            28         79        11        12  28079011_12_8  2025    1    4
# 4            28         79        11        12  28079011_12_8  2025    1    5
#
#      H01 V01  ...    H20 V20    H21 V21    H22 V22    H23 V23    H24 V24
# 0   30.0   V  ...   75.0   V  249.0   V  306.0   V  219.0   V  191.0   V
# 1  150.0   V  ...   49.0   V   41.0   V   56.0   V   38.0   V   25.0   V
# 2   17.0   V  ...  175.0   V  212.0   V  152.0   V   63.0   V   99.0   V
# 3  173.0   V  ...   61.0   V   69.0   V   76.0   V   68.0   V   56.0   V
# 4   68.0   V  ...   40.0   V   33.0   V   32.0   V   30.0   V   22.0   V
#
# [5 rows x 56 columns]
